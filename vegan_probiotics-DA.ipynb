# %% [raw]
# I want to compare the prices of these stores that offer for Probiotics and digestion-related vegan supplements. Scrape this site and also the Healthy Planet Canada website for the vegan probiotics and create a Google Spreadsheet named 'Supplements' with all the products matching these criteria, and format the table so I can easily compare prices. Specify product name, price, category, rating, and store.

# %%
from bs4 import BeautifulSoup
from requests_html import HTMLSession
import pandas as pd

# %%
from bs4 import BeautifulSoup
from requests_html import AsyncHTMLSession
import nest_asyncio
import pandas as pd

nest_asyncio.apply()

asession = AsyncHTMLSession()

async def get_vegan(url):
    
    response = await asession.get(url)
    await response.html.arender()

    ol_tag = response.html.find('ol[class_="products list items product-items UNX-grid-block"]')
    pretty = ol_tag.prettify()
    html = pretty_soup

    if ol_tag:
        print("Tag with data-container found:")
        print(ol_tag.html)
        #print("Content of the tag:")
        #print(ol_tag.text)
    else:
        print("No tag with the specified data-container attribute was found.")
        
import asyncio
url = 'https://instore.healthyplanetcanada.com/catalogsearch/result/?q=vegan+probiotics&rows=160&page=1'
asyncio.run(get_vegan(url))
# Out:
# [INFO] Starting Chromium download.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 29
#      27 import asyncio
#      28 url = 'https://instore.healthyplanetcanada.com/catalogsearch/result/?q=vegan+probiotics&rows=160&page=1'
# ---> 29 asyncio.run(get_vegan(url))
#
# File c:\Users\antuj\Projects\Data_Science\Jupyter_Notebooks\Work\Web_Scraping\Vegan_Probiotics\.venv\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\antuj\Projects\Data_Science\Jupyter_Notebooks\Work\Web_Scraping\Vegan_Probiotics\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
# ...

# %%
from bs4 import BeautifulSoup
from requests_html import AsyncHTMLSession
import pandas as pd

url = 'https://instore.healthyplanetcanada.com/catalogsearch/result/?q=vegan+probiotics&rows=160&page=1'
session = HTMLSession()
response = await session.get(url)
js_render = await response.html.arender()
#response = requests.get(url)
#HEADERS = {
#    'Accept': 'application/json, text/javascript, */*; q=0.01',
#   'Accept-Encoding': 'gzip, deflate, br, zstd',
#    'Accept-Language': 'en-US,en;q=0.5',
#    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:138.0) Gecko/20100101 Firefox/138.0'
#}

if response == 200:

    ol_tag = response.html.find('ol[class_="products list items product-items UNX-grid-block"]')
    #soup = BeautifulSoup(response.text, 'html.parser')
    #tag = soup.find('div', class_= 'product details product-item-details')
    pretty = ol_tag.prettify()
    html = pretty_soup

    if ol_tag:
        print("Tag with data-container found:")
        print(ol_tag.html)
        #print("Content of the tag:")
        #print(ol_tag.text)
    else:
        print("No tag with the specified data-container attribute was found.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       6 session = HTMLSession()
#       7 response = session.get(url)
# ----> 8 js_render = await response.html.arender()
#       9 #response = requests.get(url)
#      10 #HEADERS = {
#      11 #    'Accept': 'application/json, text/javascript, */*; q=0.01',
#    (...)     14 #    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:138.0) Gecko/20100101 Firefox/138.0'
#      15 #}
#      17 if response == 200:
#
# File c:\Users\antuj\Projects\Data_Science\Jupyter_Notebooks\Work\Web_Scraping\Vegan_Probiotics\.venv\Lib\site-packages\requests_html.py:615, in HTML.arender(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = 'https://instore.healthyplanetcanada.com/catalogsearch/result/?q=vegan+probiotics&rows=160&page=1'
response = requests.get(url, headers=HEADERS)
HEADERS = {
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Accept-Language': 'en-US,en;q=0.5',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:138.0) Gecko/20100101 Firefox/138.0'
}


if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    tag = soup.find('div', id= 'product details-product-item-details')
    product_detail = tag
    print(product_detail)
# Out:
# None
